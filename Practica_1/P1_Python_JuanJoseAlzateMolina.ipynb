# %% [markdown]
# Práctica 1 - Introducción al uso de Python y Numpy
#
# Juan José Alzate Molina.  C.C. 1007232151

# %% [markdown]
# Importar libreiria numpy y matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# a) Cree el siguiente par de vectores:
# a = [67.1,1, -0.3, 5.2, -6], b= [1, 3, 2.2, 5.1, 1]

# %%
a = np.array([67.1, 1, -0.3, 5.2, -6])
b = np.array([1, 3, 2.2, 5.1, 1])
print(a)
print(b)
# Out:
# [67.1  1.  -0.3  5.2 -6. ]
# [1.  3.  2.2 5.1 1. ]

# %% [markdown]
# b) Implemente la multiplicación escalar de a.b ¿Qué se debe realizar para poder multiplicar los dos vectores?

# %%
c = np.dot(a,b)
print(c)
# Out:
# 89.96

# %% [markdown]
#       Ambos vectores deben tener el mismo tamaño para realizar la multiiplicación escalar

# %% [markdown]
# c) Implemente la multiplicación punto a punto de a.b.

# %%
d = a*b
print(d)
# Out:
# [67.1   3.   -0.66 26.52 -6.  ]

# %% [markdown]
# d) Construya la siguiente matriz:
# 𝐴=[2 −1 −3
# 4 -1.5 −2.5
# 7.3 −0.9 -0.2]

# %%
m = np.array([[2,-1,-3],[4,-1.5,-2.5],[7.3,-0.9,-0.2]])
print(m)
# Out:
# [[ 2.  -1.  -3. ]
#  [ 4.  -1.5 -2.5]
#  [ 7.3 -0.9 -0.2]]

# %% [markdown]
# e) Obtenga su transpuesta AT.

# %%
n = np.transpose(m)
print(n)
# Out:
# [[ 2.   4.   7.3]
#  [-1.  -1.5 -0.9]
#  [-3.  -2.5 -0.2]]

# %% [markdown]
# f) Consulte la función de los siguientes comandos de la librería numpy: ones, round, ceil, floor, implemente cada función para ejemplificar su uso.

# %% [markdown]
#       ones: Crea un array de la forma y tipo de dato especificado, llena con 1s

# %%
k = np.ones((2,3), dtype=int)
print(k)
# Out:
# [[1 1 1]
#  [1 1 1]]

# %% [markdown]
#     round: Redondea un numero o array a una cantidad de decimales especificada

# %%
l = np.pi
l = np.round(l,4)
print(l)
# Out:
# 3.1416

# %% [markdown]
#     ceil: redondea un numero o array al número entero más cercano sobre el valor del argumento

# %%
o = np.array([-1.7, -1.5, -0.2, 0.2, 1.5, 1.7, 2.0])
o = np.ceil(o)
print(o)
# Out:
# [-1. -1. -0.  1.  2.  2.  2.]

# %% [markdown]
#     floor: redondea un numero o array al número entero más cercano por debajo del valor del argumento

# %%
p = np.array([-1.7, -1.5, -0.2, 0.2, 1.5, 1.7, 2.0])
p = np.floor(p)
print(p)
# Out:
# [-2. -2. -1.  0.  1.  1.  2.]

# %% [markdown]
# g) Acceda al valor de la primera fila, tercera columna de la matriz A, imprímalo en consola.

# %%
print(m[0][2])
# Out:
# -3.0

# %% [markdown]
# h) Obtenga la segunda fila de dicha matriz, imprímalo en consola.

# %%
print(m[1])
# Out:
# [ 4.  -1.5 -2.5]

# %% [markdown]
# i) Consulte el comando para conocer las dimensiones de una matriz, utilícelo con la matriz A e imprímalo en consola.

# %%
print(m.shape)
# Out:
# (3, 3)

# %% [markdown]
# j) Construya la función 𝑦[𝑛]=sin (𝜋∗0.18𝑛) en el intervalo 0 <= n <= 80.

# %%
r = np.arange(0,81,1)
y = np.sin(np.pi*0.18*r)
plt.plot(r,y)

# %% [markdown]
# k) Construya otra senoidal 𝑦2[𝑛]=cos(2𝜋∗0.03𝑛)

# %%
y2 = np.cos(2*np.pi*0.03*r)
plt.plot(r,y2)

# %% [markdown]
# l) Genere una tercera señal que sea la suma de estas dos señales, es decir 𝑠[𝑛]=y[n]+𝑦2[𝑛] y una cuarta, que sea el producto de estas, 𝑡[𝑛]=y[n].𝑦2[𝑛].

# %%
s = y + y2
t = y * y2

# %% [markdown]
# m) Graficar en la misma figura las señales y[n] y y2[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje.

# %%
fig, ax = plt.subplots()
ax.plot(r, y, label='y[n]')
ax.plot(r, y2, label='y2[n]')
plt.xlabel(' eje x')
plt.ylabel('eje y')
ax.set_title("y[n] vs. y2[n]")
ax.legend(loc='upper right')

# %% [markdown]
# n) Graficar en la misma figura las señales s[n] y t[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje.

# %%
fig, ax = plt.subplots()
ax.plot(r, s, label='s[n]')
ax.plot(r, t, label='t[n]')
plt.xlabel(' eje x')
plt.ylabel('eje y')
ax.set_title("s[n] vs. t[n]")
ax.legend(loc='upper right')

# %% [markdown]
# **¡RETO!**
#
# Escribir una función que reciba un diccionario con las notas de los alumnos de un curso y devuelva una serie con la nota mínima, la máxima, media y la desviación típica.

# %%
Notas = { "Juan Arias" : 4.25,  "Daniela Rojas": 3.56, "Daniel Caro": 4.54, "Santiago Gomez": 4.12, "Marcela Hoyos": 2.88, "Laura Rojas": 3.84 }

# %%
def serie(dic):
  resultado = [min(Notas.values()), max(Notas.values()), np.std(list(Notas.values()))]
  return resultado

# %%
print(serie(Notas))
# Out:
# [2.88, 4.54, 0.5373934002820157]
